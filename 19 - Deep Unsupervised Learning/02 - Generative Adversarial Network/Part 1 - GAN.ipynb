# %%
from IPython.display import Image, Video

# %% [markdown]
# # Pilih mana yang Asli dan Palsu

# %%
Image("assets/najwa.png", width=400)

# %% [markdown]
# # Progression

# %%
Video("assets/progression.mp4", width=800)
# Out:
# <video src="assets/progression.mp4" controls  width="800" >
#       Your browser does not support the <code>video</code> element.
#     </video>
