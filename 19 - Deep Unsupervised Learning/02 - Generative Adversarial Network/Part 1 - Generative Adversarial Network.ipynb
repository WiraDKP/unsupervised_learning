# %%
from luwiji.gan import illustration

# %% [markdown]
# # Generative Model -> Model yang bisa sampling data
#
# Generative model berusaha mempelajari distribusi dari data, dan kemudian dapat membuat data baru dengan sampling darii distribusi tersebut.

# %% [markdown]
# ## Contoh 1:

# %%
illustration.generative

# %% [markdown]
# ## Contoh 2:
#
# [[Video] Latent Space Visualization](https://youtu.be/UIijTdUENW4)

# %% [markdown]
# ## Contoh 3:
# [[Video] GAN Training progress](https://youtu.be/6BMVLB6uVK8)

# %%
illustration.najwa

# %% [markdown]
# ## Contoh 4:
#
# coba perhatikan apa yang dilakukan generator di aplikasi [GAN Lab](https://poloclub.github.io/ganlab/)?<br>
# Jawab. Mencocokkan distribusi

# %% [markdown]
# # Adversarial Training -> Training dengan mengandalkan oposisi
#
# ```
# adversarial (adjective)
#     involving or characterized by conflict or opposition.
# ```

# %% [markdown]
# # GAN Architecture

# %%
illustration.gan

# %% [markdown]
# # Training GAN

# %%
illustration.train_D

# %%
illustration.train_G

# %% [markdown]
# # Conditional GAN (CGAN)

# %%
illustration.cgan
